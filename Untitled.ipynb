# %%
import time
import os
from array import *
rows = 8;
columns = 8;

# Using Same Functions for both Player and Computer Thug Life Jo Ukharna ha Ukhaar lo Shehla Shocked Bhai Rocked
player = 'B' 
enemy = 'W'

grid= [["-" , "-" , "-" , "-" , "-" , "-" , "-" , "-"], 
       ["-" , "-" , "-" , "-" , "-" , "-" , "-" , "-"],
       ["-" , "-" , "-" , "-" , "-" , "-" , "-" , "-"], 
       ["-" , "-" , "-" , "W" , "B" , "-" , "-" , "-"], 
       ["-" , "-" , "-" , "B" , "W" , "-" , "-" , "-"], 
       ["-" , "-" , "-" , "-" , "-" , "-" , "-" , "-"], 
       ["-" , "-" , "-" , "-" , "-" , "-" , "-" , "-"], 
       ["-" , "-" , "-" , "-" , "-" , "-" , "-" , "-"]]

# %%
def printMatrix():
    for i in range(rows):
        print('[ ', end='')
        for j in range(columns):
            print(grid[i][j], end=' ')
            if j != columns-1:
                print(', ',end='')
        print(']')

# %%
def CheckDown(r, c):
    row = r
    valid = False
    
    row = row + 1
    
    while True:
        #print(row,c,grid[row][c])
        #print(row+1,c,grid[row+1][c])
        #print(row+2,c,grid[row+2][c])
        if grid[row][c] == enemy:
            #print("Enemy can sandwich", row, ', ', c)
            valid = True
        else:
            if valid == False:
                #print("No Enemy Found")
                break
            else:
                #print("End Point Reached")
                #print(grid[row][c])
                if grid[row][c] == player:
                    for i in range(r,row):
                        #print("i: ", i)
                        grid[i][c] = player
                break
        #print("Reached End of Loop")        
        row = row+1
            
    
    if valid == True:
        return True
    else:
        return False
    
def process(r,c):
    return CheckDown(r,c)
    #printMatrix()
    
    
def Player():
    printMatrix()
    print("User Turn\n")
    r = int(input("Enter Row: "))
    c = int(input("Enter Column: "))

    if grid[r][c] != '-':
        print("Not Valid")
        pass

    valid = process(r,c)

    if valid == False:
        print("Not Valid")
        pass
        
    print("\n------------------------------------------------\n")
    printMatrix()
    
while True:
    Player()
    break
# Out:
# [ - , - , - , - , - , - , - , - ]
# [ - , - , - , - , - , - , - , - ]
# [ - , - , - , - , - , - , - , - ]
# [ - , - , - , W , B , - , - , - ]
# [ - , - , - , B , W , - , - , - ]
# [ - , - , - , - , - , - , - , - ]
# [ - , - , - , - , - , - , - , - ]
# [ - , - , - , - , - , - , - , - ]
# User Turn
#
# Enter Row: 2
# Enter Column: 3
# 3 3 W
# Enemy can sandwich 3 ,  3
# Reached End of Loop
# 4 3 B
# End Point Reached
# B
# i:  2
# i:  3
#
# ------------------------------------------------
#
# [ - , - , - , - , - , - , - , - ]
# [ - , - , - , - , - , - , - , - ]
# [ - , - , - , B , - , - , - , - ]
# [ - , - , - , B , B , - , - , - ]
# [ - , - , - , B , W , - , - , - ]
# [ - , - , - , - , - , - , - , - ]
# [ - , - , - , - , - , - , - , - ]
# [ - , - , - , - , - , - , - , - ]

# %%
def CheckLeft():
    if grid[r][c] == enemy:
        return True;
    return False;

def CheckLeftDown():
    if grid[r][c] == enemy:
        return True

# %%
def CheckRight():
    if grid[r][c] == enemy:
        return True;
    return False;

def CheckRightDown():
    if grid[r][c] == enemy:
        return True;
    return False;

# %%
def CheckDown():
    if grid[r][c] == enemy:
        return True;
    return False;
